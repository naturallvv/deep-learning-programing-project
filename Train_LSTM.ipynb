# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import *
from sklearn.preprocessing import *
from torch.utils.data import DataLoader, TensorDataset
import torch
import torch.nn as nn
import torch.optim as optim

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')
# Out:
# Using device: cuda

# %%
train_data = pd.read_csv("C:/Users/user/Desktop/deep-learning-programing-project/train_data.csv")
test_data = pd.read_csv("C:/Users/user/Desktop/deep-learning-programing-project/test_data.csv")

# %%
train_data = train_data.drop("LABEL", axis=1).T
test_data = test_data.drop("LABEL", axis=1).T
test_data.head()
# Out:
#            0        1       2       3      4      5       6      7       8    \
# FLUX.1  119.88  5736.59  844.48 -826.00 -39.57  14.28 -150.48 -10.06  454.66
# FLUX.2  100.21  5699.98  817.49 -827.31 -15.88  10.63 -141.72 -12.78  440.60
# FLUX.3   86.46  5717.16  770.07 -846.12  -9.16  14.56 -157.60 -13.16  382.29
# FLUX.4   48.68  5692.73  675.01 -836.03  -6.37  12.42 -184.60  -9.81  361.63
# FLUX.5   46.12  5663.83  605.52 -745.50 -16.13  12.07 -164.89 -18.91  298.63
#
#            9    ...   560   561    562    563     564     565   566    567  \
# FLUX.1  187.40  ...  5.66  4.36 -79.95 -63.42  144.47  374.46 -0.36 -54.01
# FLUX.2  209.60  ...  7.83  2.22 -79.13 -59.78   20.09  326.06  4.96 -44.13
# FLUX.3  199.91  ... -4.39  5.61 -81.07 -64.16  147.47  319.87  6.25 -41.23
# FLUX.4  179.62  ... -0.62 -1.44 -72.25 -61.07  109.18  338.23  4.20 -42.82
# FLUX.5  171.21  ... -5.23 -0.05 -79.71 -41.74  100.87  251.54  8.26 -39.47
#
#           568      569
# FLUX.1  91.36  3071.19
# FLUX.2  85.60  2782.53
# FLUX.3  48.81  2608.69
# FLUX.4  48.69  2325.47
# FLUX.5  70.05  2089.37
#
# [5 rows x 570 columns]

# %%
median_values_train = train_data.median(axis=1)
median_values_test = test_data.median(axis=1)

# %%
median_train_df = pd.DataFrame(median_values_train, columns=['Median'])
median_test_df = pd.DataFrame(median_values_test, columns=['Median'])

# %%
median_train_df
# Out:
#            Median
# FLUX.1      -0.71
# FLUX.2      -0.89
# FLUX.3      -0.74
# FLUX.4      -0.40
# FLUX.5      -0.61
# ...           ...
# FLUX.3193    3.50
# FLUX.3194   -0.68
# FLUX.3195    0.36
# FLUX.3196    0.90
# FLUX.3197    1.43
#
# [3197 rows x 1 columns]

# %%
median_test_df
# Out:
#            Median
# FLUX.1      1.195
# FLUX.2      0.410
# FLUX.3     -1.125
# FLUX.4     -0.880
# FLUX.5     -1.495
# ...           ...
# FLUX.3193   7.150
# FLUX.3194  -4.385
# FLUX.3195  -4.995
# FLUX.3196  -5.135
# FLUX.3197  -3.785
#
# [3197 rows x 1 columns]

# %%
median_train_df.shape,median_test_df.shape
# Out:
# ((3197, 1), (3197, 1))

# %%
scaler = MinMaxScaler()

scaled_train_data = scaler.fit_transform(median_train_df)
scaled_test_data = scaler.transform(median_test_df)

scaled_train_df = pd.DataFrame(scaled_train_data, index=median_train_df.index, columns=median_train_df.columns)
scaled_test_df = pd.DataFrame(scaled_test_data, index=median_test_df.index, columns=median_test_df.columns)

# %%
def create_dataset(data, time_step=1):
    X, Y = [], []
    for i in range(len(data)-time_step-1):
        a = data[i:(i+time_step), 0]
        X.append(a)
        Y.append(data[i + time_step, 0])
    return np.array(X), np.array(Y)

time_step = 100

X_train, Y_train = create_dataset(scaled_train_df.values, time_step)
X_test, Y_test = create_dataset(scaled_test_df.values, time_step)

X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

X_train.shape,X_test.shape
# Out:
# ((3096, 100, 1), (3096, 100, 1))

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset

# LSTM 모델 정의
class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(LSTMModel, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        h_0 = torch.zeros(1, x.size(0), hidden_size).to(device)
        c_0 = torch.zeros(1, x.size(0), hidden_size).to(device)
        output, (h_n, c_n) = self.lstm(x, (h_0, c_0))
        output = self.fc(output[:, -1, :])
        return output

# 하이퍼파라미터 설정
input_size = X_train.shape[2]
#default 50
hidden_size = 50
output_size = 1
num_epochs = 100
#default 0.001
learning_rate = 0.001

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = LSTMModel(input_size, hidden_size, output_size).to(device)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
train_dataset = TensorDataset(torch.tensor(X_train, dtype=torch.float32), torch.tensor(Y_train, dtype=torch.float32))
test_dataset = TensorDataset(torch.tensor(X_test, dtype=torch.float32), torch.tensor(Y_test, dtype=torch.float32))

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# %%
# 모델 학습
for epoch in range(num_epochs):
    model.train()
    for X_batch, y_batch in train_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        
        # Forward pass
        outputs = model(X_batch)
        loss = criterion(outputs, y_batch.unsqueeze(1))
        
        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    
    # 테스트 데이터로 평가
    model.eval()
    test_loss = 0
    with torch.no_grad():
        for X_batch, y_batch in test_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            outputs = model(X_batch)
            loss = criterion(outputs, y_batch.unsqueeze(1))
            test_loss += loss.item()
    
    print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {loss.item():.4f}, Test Loss: {test_loss/len(test_loader):.4f}')
# Out:
# Epoch [1/100], Train Loss: 0.1313, Test Loss: 0.1346
# Epoch [2/100], Train Loss: 0.1153, Test Loss: 0.1091
# Epoch [3/100], Train Loss: 0.1057, Test Loss: 0.0887
# Epoch [4/100], Train Loss: 0.1046, Test Loss: 0.0827
# Epoch [5/100], Train Loss: 0.1039, Test Loss: 0.0789
# Epoch [6/100], Train Loss: 0.1034, Test Loss: 0.0757
# Epoch [7/100], Train Loss: 0.1033, Test Loss: 0.0729
# Epoch [8/100], Train Loss: 0.1036, Test Loss: 0.0703
# Epoch [9/100], Train Loss: 0.1047, Test Loss: 0.0681
# Epoch [10/100], Train Loss: 0.1065, Test Loss: 0.0662
# Epoch [11/100], Train Loss: 0.1090, Test Loss: 0.0647
# Epoch [12/100], Train Loss: 0.1117, Test Loss: 0.0634
# Epoch [13/100], Train Loss: 0.1140, Test Loss: 0.0622
# Epoch [14/100], Train Loss: 0.1147, Test Loss: 0.0608
# Epoch [15/100], Train Loss: 0.1135, Test Loss: 0.0590
# Epoch [16/100], Train Loss: 0.1108, Test Loss: 0.0571
# Epoch [17/100], Train Loss: 0.1074, Test Loss: 0.0553
# Epoch [18/100], Train Loss: 0.1036, Test Loss: 0.0534
# Epoch [19/100], Train Loss: 0.0998, Test Loss: 0.0518
# Epoch [20/100], Train Loss: 0.0962, Test Loss: 0.0502
# Epoch [21/100], Train Loss: 0.0929, Test Loss: 0.0488
# Epoch [22/100], Train Loss: 0.0900, Test Loss: 0.0476
# Epoch [23/100], Train Loss: 0.0875, Test Loss: 0.0466
# Epoch [24/100], Train Loss: 0.0855, Test Loss: 0.0457
# Epoch [25/100], Train Loss: 0.0838, Test Loss: 0.0449
# Epoch [26/100], Train Loss: 0.0824, Test Loss: 0.0443
# Epoch [27/100], Train Loss: 0.0813, Test Loss: 0.0437
# Epoch [28/100], Train Loss: 0.0803, Test Loss: 0.0432
# Epoch [29/100], Train Loss: 0.0793, Test Loss: 0.0428
# Epoch [30/100], Train Loss: 0.0785, Test Loss: 0.0423
# Epoch [31/100], Train Loss: 0.0777, Test Loss: 0.0419
# Epoch [32/100], Train Loss: 0.0769, Test Loss: 0.0415
# Epoch [33/100], Train Loss: 0.0761, Test Loss: 0.0411
# Epoch [34/100], Train Loss: 0.0753, Test Loss: 0.0407
# Epoch [35/100], Train Loss: 0.0741, Test Loss: 0.0403
# Epoch [36/100], Train Loss: 0.0725, Test Loss: 0.0399
# Epoch [37/100], Train Loss: 0.0711, Test Loss: 0.0397
# Epoch [38/100], Train Loss: 0.0705, Test Loss: 0.0395
# Epoch [39/100], Train Loss: 0.0698, Test Loss: 0.0394
# Epoch [40/100], Train Loss: 0.0681, Test Loss: 0.0392
# Epoch [41/100], Train Loss: 0.0688, Test Loss: 0.0394
# Epoch [42/100], Train Loss: 0.0765, Test Loss: 0.0403
# Epoch [43/100], Train Loss: 0.0799, Test Loss: 0.0400
# Epoch [44/100], Train Loss: 0.0762, Test Loss: 0.0410
# Epoch [45/100], Train Loss: 0.0718, Test Loss: 0.0396
# Epoch [46/100], Train Loss: 0.0745, Test Loss: 0.0400
# Epoch [47/100], Train Loss: 0.0784, Test Loss: 0.0398
# Epoch [48/100], Train Loss: 0.0739, Test Loss: 0.0404
# Epoch [49/100], Train Loss: 0.0749, Test Loss: 0.0397
# Epoch [50/100], Train Loss: 0.0733, Test Loss: 0.0396
# Epoch [51/100], Train Loss: 0.0828, Test Loss: 0.0403
# Epoch [52/100], Train Loss: 0.0807, Test Loss: 0.0399
# Epoch [53/100], Train Loss: 0.0682, Test Loss: 0.0392
# Epoch [54/100], Train Loss: 0.0710, Test Loss: 0.0388
# Epoch [55/100], Train Loss: 0.0662, Test Loss: 0.0387
# Epoch [56/100], Train Loss: 0.0710, Test Loss: 0.0389
# Epoch [57/100], Train Loss: 0.0652, Test Loss: 0.0387
# Epoch [58/100], Train Loss: 0.0710, Test Loss: 0.0390
# Epoch [59/100], Train Loss: 0.0653, Test Loss: 0.0388
# Epoch [60/100], Train Loss: 0.0741, Test Loss: 0.0391
# Epoch [61/100], Train Loss: 0.0655, Test Loss: 0.0388
# Epoch [62/100], Train Loss: 0.0696, Test Loss: 0.0387
# Epoch [63/100], Train Loss: 0.0646, Test Loss: 0.0386
# Epoch [64/100], Train Loss: 0.0717, Test Loss: 0.0388
# Epoch [65/100], Train Loss: 0.0647, Test Loss: 0.0387
# Epoch [66/100], Train Loss: 0.0654, Test Loss: 0.0384
# Epoch [67/100], Train Loss: 0.0735, Test Loss: 0.0388
# Epoch [68/100], Train Loss: 0.0658, Test Loss: 0.0389
# Epoch [69/100], Train Loss: 0.0638, Test Loss: 0.0383
# Epoch [70/100], Train Loss: 0.0620, Test Loss: 0.0386
# Epoch [71/100], Train Loss: 0.0662, Test Loss: 0.0386
# Epoch [72/100], Train Loss: 0.0660, Test Loss: 0.0387
# Epoch [73/100], Train Loss: 0.0678, Test Loss: 0.0387
# Epoch [74/100], Train Loss: 0.0658, Test Loss: 0.0385
# Epoch [75/100], Train Loss: 0.0673, Test Loss: 0.0383
# Epoch [76/100], Train Loss: 0.0646, Test Loss: 0.0382
# Epoch [77/100], Train Loss: 0.0677, Test Loss: 0.0382
# Epoch [78/100], Train Loss: 0.0635, Test Loss: 0.0382
# Epoch [79/100], Train Loss: 0.0651, Test Loss: 0.0380
# Epoch [80/100], Train Loss: 0.0653, Test Loss: 0.0382
# Epoch [81/100], Train Loss: 0.0646, Test Loss: 0.0382
# Epoch [82/100], Train Loss: 0.0665, Test Loss: 0.0381
# Epoch [83/100], Train Loss: 0.0629, Test Loss: 0.0381
# Epoch [84/100], Train Loss: 0.0635, Test Loss: 0.0379
# Epoch [85/100], Train Loss: 0.0647, Test Loss: 0.0380
# Epoch [86/100], Train Loss: 0.0634, Test Loss: 0.0381
# Epoch [87/100], Train Loss: 0.0646, Test Loss: 0.0379
# Epoch [88/100], Train Loss: 0.0626, Test Loss: 0.0380
# Epoch [89/100], Train Loss: 0.0638, Test Loss: 0.0378
# Epoch [90/100], Train Loss: 0.0630, Test Loss: 0.0379
# Epoch [91/100], Train Loss: 0.0637, Test Loss: 0.0379
# Epoch [92/100], Train Loss: 0.0631, Test Loss: 0.0379
# Epoch [93/100], Train Loss: 0.0632, Test Loss: 0.0378
# Epoch [94/100], Train Loss: 0.0630, Test Loss: 0.0378
# Epoch [95/100], Train Loss: 0.0630, Test Loss: 0.0378
# Epoch [96/100], Train Loss: 0.0629, Test Loss: 0.0377
# Epoch [97/100], Train Loss: 0.0629, Test Loss: 0.0377
# Epoch [98/100], Train Loss: 0.0629, Test Loss: 0.0377
# Epoch [99/100], Train Loss: 0.0628, Test Loss: 0.0377
# Epoch [100/100], Train Loss: 0.0628, Test Loss: 0.0377

# %%
# 모델 예측 및 평가
model.eval()
predictions = []
actuals = []
with torch.no_grad():
    for X_batch, y_batch in test_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        outputs = model(X_batch)
        predictions.append(outputs.cpu().numpy())
        actuals.append(y_batch.cpu().numpy())

# Flatten the lists
predictions = np.concatenate(predictions)
actuals = np.concatenate(actuals)

# 예측 결과 시각화
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(actuals, label='Actual')
plt.plot(predictions, label='Predicted')
plt.legend()
plt.show()
